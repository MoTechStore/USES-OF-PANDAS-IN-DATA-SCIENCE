# %%
# loading of data
import pandas as pd
from pandas import read_csv
filename = 'movie.csv'
data = read_csv(filename)
data.head(5)
# Out:
#    movieId                    title                      genres
# 0        1         Toy Story (1995)              Comedy|Romance
# 1        2              Moses(1990)  Adventure|Children|Fantasy
# 2        3  Grumpier Old Men (1995)              Comedy|Romance
# 3        2              Moses(1990)  Adventure|Children|Fantasy
# 4        4                BoB(2000)        Comedy|Drama|Romance

# %%
data.head()
# Out:
#    movieId                    title                      genres
# 0        1         Toy Story (1995)              Comedy|Romance
# 1        2              Moses(1990)  Adventure|Children|Fantasy
# 2        3  Grumpier Old Men (1995)              Comedy|Romance
# 3        2              Moses(1990)  Adventure|Children|Fantasy
# 4        4                BoB(2000)        Comedy|Drama|Romance

# %%
# sorting in Ascending order
data.sort_values('movieId')
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 1           2                                        Moses(1990)
# 3           2                                        Moses(1990)
# 5           2                                        Moses(1990)
# 2           3                            Grumpier Old Men (1995)
# 4           4                                          BoB(2000)
# 6           5                 Father of the Bride Part II (1995)
# 7           6                                        Heat (1995)
# 8           7                                     Sabrina (1995)
# 9           8                                Tom and Huck (1995)
# 10          9                                Sudden Death (1995)
# 11         10                                   GoldenEye (1995)
# 12         11                     American President, The (1995)
# ...

# %%
# sorting in descending order
data['movieId'].sort_values(ascending=False)
# Out:
# 9743    193609
# 9742    193587
# 9741    193585
# 9740    193583
# 9739    193581
# 9738    193579
# 9737    193573
# 9736    193571
# 9735    193567
# 9734    193565
# 9733    191005
# 9732    190221
# 9731    190219
# 9730    190215
# 9729    190213
# 9728    190209
# 9727    190207
# 9726    190183
# 9725    189713
# 9724    189547
# 9723    189381
# 9722    189333
# 9721    189111
# 9720    189043
# 9719    188833
# 9718    188797
# 9717    188751
# 9716    188675
# 9715    188301
# 9714    188189
#          ...
# 29          28
# 28          27
# 27          26
# 26          25
# 25          24
# 24          23
# 23          22
# 22          21
# 21          20
# 20          19
# 19          18
# 18          17
# 17          16
# 16          15
# 15          14
# 14          13
# 13          12
# 12          11
# 11          10
# 10           9
# 9            8
# 8            7
# 7            6
# 6            5
# 4            4
# 2            3
# 5            2
# ...
