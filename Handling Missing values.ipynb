# %%
# loading of data
import pandas as pd
from pandas import read_csv
filename = 'movie.csv'
data = read_csv(filename)
data.head(5)
# Out:
#    movieId                    title                      genres
# 0      1.0         Toy Story (1995)                         NaN
# 1      2.0              Moses(1990)                         NaN
# 2      NaN  Grumpier Old Men (1995)              Comedy|Romance
# 3      2.0              Moses(1990)  Adventure|Children|Fantasy
# 4      4.0                      NaN        Comedy|Drama|Romance

# %%
data.head()
# Out:
#    movieId                    title                      genres
# 0      1.0         Toy Story (1995)                         NaN
# 1      2.0              Moses(1990)                         NaN
# 2      NaN  Grumpier Old Men (1995)              Comedy|Romance
# 3      2.0              Moses(1990)  Adventure|Children|Fantasy
# 4      4.0                      NaN        Comedy|Drama|Romance

# %%
data.dropna(how='any')
# Out:
#        movieId                                              title  \
# 3          2.0                                        Moses(1990)
# 5          2.0                                        Moses(1990)
# 6          5.0                 Father of the Bride Part II (1995)
# 7          6.0                                        Heat (1995)
# 8          7.0                                     Sabrina (1995)
# 9          8.0                                Tom and Huck (1995)
# 10         9.0                                Sudden Death (1995)
# 11        10.0                                   GoldenEye (1995)
# 12        11.0                     American President, The (1995)
# 13        12.0                 Dracula: Dead and Loving It (1995)
# 14        13.0                                       Balto (1995)
# 15        14.0                                       Nixon (1995)
# 16        15.0                            Cutthroat Island (1995)
# ...
